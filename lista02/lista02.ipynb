# %% [markdown]
# # Aula prática 02 - Busca para jogos

# %% [markdown]
# 1)
# Minimax em arvore de jogo
# Considere a árvore de jogo abaixo, em que os jogadores MAX e MIN se alternam a cada
# nıvel.
# A arvore possui profundidade 3 e os valores nos nós folhas representam utilidade
# para o jogador MAX.

# %% [markdown]
# ![Captura de tela 2025-04-30 162805.png](data:image/png;base64,...)

# %% [markdown]
# 1)
# Implemente em Python o algoritmo Minimax para percorrer a árvore e encontrar o
# valor ótimo na raiz (nó A).
# Seu código deve:
# • Representar a árvore de forma adequada (ex: dicionário ou lista de adjacência);
# • Executar a recursão alternando entre MAX e MIN;
# • Exibir a ordem de chamadas e o valor retornado em cada nó.

# %%
import numpy as np
import math as mt

# %%
def min(values:dict)->float:
    return 1
def max(values:dict)->float:
    return 1

# %%
def minmax (root,isMaximizing:bool)->float:
    if isInstance(node,int):
        return node
    return -math.inf
